# %%
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
from matplotlib import pyplot
import numpy as np
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
batch_size_exp = 1
epoch_exp = 7
neurons_exp = 10
predict_values_exp = 72
lag_exp=24

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return Series(diff)

# %%
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
# scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled

# %%
# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
        model.reset_states()
    return model

# %%
# make a one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    #print(X)
    yhat = model.predict(X, batch_size=1)
    return yhat[0,0]

# %%
''' Loading data '''
import pandas as pd
series = pd.read_csv('/content/drive/My Drive/T1.csv',index_col="Date/Time")
series.head()
# Out:
#                   LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                              ...
# 01 01 2018 00:00           380.047791  ...          259.994904
# 01 01 2018 00:10           453.769196  ...          268.641113
# 01 01 2018 00:20           306.376587  ...          272.564789
# 01 01 2018 00:30           419.645905  ...          271.258087
# 01 01 2018 00:40           380.650696  ...          265.674286
#
# [5 rows x 4 columns]

# %%
#del series['Air temperature | (\'C)']
del series['LV ActivePower (kW)']
del series['Wind Speed (m/s)']
del series['Theoretical_Power_Curve (KWh)']
series.head()
# Out:
#                   Wind Direction (°)
# Date/Time
# 01 01 2018 00:00          259.994904
# 01 01 2018 00:10          268.641113
# 01 01 2018 00:20          272.564789
# 01 01 2018 00:30          271.258087
# 01 01 2018 00:40          265.674286

# %%
for i in range(0,10):
  series = series[:-1]
series.tail()
# Out:
#                   Wind Direction (°)
# Date/Time
# 31 12 2018 21:30           79.699562
# 31 12 2018 21:40           80.132507
# 31 12 2018 21:50           80.081612
# 31 12 2018 22:00           80.452248
# 31 12 2018 22:10           80.960693

# %%
  series.shape
# Out:
# (50520, 1)

# %%
# transform data to be stationary
raw_values = series.values
diff_values = difference(raw_values, 1)

# %%
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, lag_exp)
supervised_values = supervised.values

# %%
# split data into train and test-sets
train, test = supervised_values[0:-predict_values_exp], supervised_values[-predict_values_exp:]

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# %%
lstm_model = fit_lstm(train_scaled, batch_size_exp, epoch_exp, neurons_exp)
# Out:
# Epoch 1/1
# 50447/50447 [==============================] - 208s 4ms/step - loss: 0.0111
# Epoch 1/1
# 50447/50447 [==============================] - 208s 4ms/step - loss: 0.0108
# Epoch 1/1
# 50447/50447 [==============================] - 209s 4ms/step - loss: 0.0107
# Epoch 1/1
# 50447/50447 [==============================] - 207s 4ms/step - loss: 0.0106
# Epoch 1/1
# 50447/50447 [==============================] - 205s 4ms/step - loss: 0.0106
# Epoch 1/1
# 50447/50447 [==============================] - 207s 4ms/step - loss: 0.0105
# Epoch 1/1
# 50447/50447 [==============================] - 206s 4ms/step - loss: 0.0104

# %%
predictions = list()
expectations = list()
test_pred = list()
for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)#batch_size_exp to 1
    '''# Start Debug prints
    print("X: %", X)
    print("yhat: %", yhat)
    # End Debug prints'''
    # Replacing value in test scaled with the predicted value.
    test_pred = [yhat] + test_pred 
    if len(test_pred) > lag_exp+1:
        test_pred = test_pred[:-1]
    if i+1<len(test_scaled):
        if i+1 > lag_exp+1:
            test_scaled[i+1] = test_pred
        else:
            test_scaled[i+1] = np.concatenate((test_pred, test_scaled[i+1, i+1:]),axis=0)

    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
    # store forecast
    expected = raw_values[len(train) + i + 1]
    if expected != 0:
        predictions.append(yhat)
        expectations.append(expected)
    print('Hour=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Hour=1, Predicted=58.545107, Expected=67.674561
# Hour=2, Predicted=53.662181, Expected=71.880203
# Hour=3, Predicted=65.297146, Expected=80.607430
# Hour=4, Predicted=103.010037, Expected=81.242447
# Hour=5, Predicted=76.252094, Expected=95.116180
# Hour=6, Predicted=87.673620, Expected=108.525902
# Hour=7, Predicted=118.726044, Expected=99.066833
# Hour=8, Predicted=103.625607, Expected=83.458061
# Hour=9, Predicted=86.000549, Expected=87.656326
# Hour=10, Predicted=81.722780, Expected=78.961700
# Hour=11, Predicted=85.245203, Expected=87.310623
# Hour=12, Predicted=92.442191, Expected=89.737091
# Hour=13, Predicted=98.515266, Expected=82.736252
# Hour=14, Predicted=64.434872, Expected=81.974297
# Hour=15, Predicted=86.103850, Expected=73.194389
# Hour=16, Predicted=76.356553, Expected=75.005074
# Hour=17, Predicted=90.671430, Expected=79.551987
# Hour=18, Predicted=70.107573, Expected=76.018478
# Hour=19, Predicted=73.373081, Expected=78.276291
# Hour=20, Predicted=80.261695, Expected=68.145531
# Hour=21, Predicted=72.545747, Expected=71.954659
# Hour=22, Predicted=73.648519, Expected=69.709587
# Hour=23, Predicted=69.908107, Expected=63.816212
# Hour=24, Predicted=63.354605, Expected=56.398918
# Hour=25, Predicted=56.976720, Expected=57.145569
# Hour=26, Predicted=59.189102, Expected=55.499611
# Hour=27, Predicted=55.557111, Expected=57.752941
# Hour=28, Predicted=55.943761, Expected=65.545662
# Hour=29, Predicted=68.004214, Expected=67.542412
# Hour=30, Predicted=68.856164, Expected=67.638237
# Hour=31, Predicted=68.975011, Expected=70.322388
# Hour=32, Predicted=68.501544, Expected=72.430473
# Hour=33, Predicted=74.299940, Expected=74.770714
# Hour=34, Predicted=75.104983, Expected=74.835281
# Hour=35, Predicted=77.843165, Expected=76.580833
# Hour=36, Predicted=75.553152, Expected=74.678101
# Hour=37, Predicted=74.899207, Expected=75.286987
# Hour=38, Predicted=76.153577, Expected=76.233170
# Hour=39, Predicted=78.824845, Expected=76.356567
# Hour=40, Predicted=76.692345, Expected=76.052834
# Hour=41, Predicted=75.906776, Expected=85.393311
# Hour=42, Predicted=86.465196, Expected=85.161186
# Hour=43, Predicted=86.550533, Expected=81.050690
# Hour=44, Predicted=81.944601, Expected=86.718536
# Hour=45, Predicted=87.535613, Expected=91.986732
# Hour=46, Predicted=92.647344, Expected=94.691391
# Hour=47, Predicted=95.746439, Expected=92.350723
# Hour=48, Predicted=93.336728, Expected=91.588493
# Hour=49, Predicted=92.603690, Expected=94.329742
# Hour=50, Predicted=94.579825, Expected=98.706261
# Hour=51, Predicted=99.900741, Expected=97.239059
# Hour=52, Predicted=98.164407, Expected=99.136337
# Hour=53, Predicted=100.204194, Expected=97.632187
# Hour=54, Predicted=98.055625, Expected=90.309258
# Hour=55, Predicted=91.252087, Expected=87.520317
# Hour=56, Predicted=88.289147, Expected=84.240913
# Hour=57, Predicted=85.315456, Expected=78.987038
# Hour=58, Predicted=79.759542, Expected=79.042793
# Hour=59, Predicted=79.706066, Expected=78.169724
# Hour=60, Predicted=78.959237, Expected=78.773773
# Hour=61, Predicted=79.809859, Expected=80.061111
# Hour=62, Predicted=80.900262, Expected=81.279243
# Hour=63, Predicted=81.951451, Expected=79.519127
# Hour=64, Predicted=80.328528, Expected=81.056862
# Hour=65, Predicted=82.004403, Expected=80.272682
# Hour=66, Predicted=81.083458, Expected=79.394409
# Hour=67, Predicted=80.236850, Expected=79.356262
# Hour=68, Predicted=80.123640, Expected=79.699562
# Hour=69, Predicted=80.583658, Expected=80.132507
# Hour=70, Predicted=80.970482, Expected=80.081612
# Hour=71, Predicted=80.981198, Expected=80.452248
# Hour=72, Predicted=81.189467, Expected=80.960693

# %%
expectations = np.array(expectations)
predictions = np.array(predictions)
print("Mean Absolute Percent Error: ", (np.mean(np.abs((expectations - predictions) / expectations))*100))
# Out:
# Mean Absolute Percent Error:  6.224189033696507

# %%
# line plot of observed vs predicted
pyplot.plot(raw_values[-predict_values_exp:], label="True")
pyplot.plot(predictions, label="Predicted")
pyplot.legend(loc='upper right')
pyplot.xlabel("Number of hours")
pyplot.ylabel("wind direction")
pyplot.show()

# %%
import pickle

# %%
Pkl_Filename = "Pickle_RL_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(lstm_model, file)

# %%
with open(Pkl_Filename, 'rb') as file:  
    Pickled_LR_Model = pickle.load(file)

Pickled_LR_Model

# %%
score = Pickled_LR_Model.score(train, test)  
# Print the Score
print("Test score: {0:.2f} %".format(100 * score))  

# Predict the Labels using the reloaded Model
Ypredict = Pickled_LR_Model.predict(test)  

Ypredict

# %%
# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(lstm_model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)
